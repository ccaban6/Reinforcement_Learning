# %% [markdown]
# ## 1. Download necessary packages and Import Dependencies

# %%
#!pip freeze
#!pip uninstall -y "stable-baselines3[extra]"
#!pip install "stable-baselines3[extra]"
#!pip install gym
#!pip uninstall -y gym

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## 2. Load Environment

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)
# Out:
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
environment_name, env
# Out:
# ('CartPole-v0',
#  <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v0>>>>>)

# %%
import numpy
import gym
print(numpy.__version__)
print(gym.__version__)
# Out:
# 1.23.0
# 0.26.2

# %%
episodes = 5
for episode in range(1, episodes + 1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        action = env.action_space.sample()
        n_state, reward, done, _, info = env.step(action)
        env.render()
        score += reward
    print("Episode: {} Score: {}".format(episode, score))
env.close()
# Out:
# Episode: 1 Score: 25.0
# Episode: 2 Score: 27.0
# Episode: 3 Score: 13.0
# Episode: 4 Score: 18.0
# Episode: 5 Score: 11.0
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\gym\envs\classic_control\cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %% [markdown]
# ## 3. Train an RL Model

# %%
## MAKE DIRECTORIES FIRST
log_path = os.path.join("Training", "Logs")

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_14
# -----------------------------
# | time/              |      |
# |    fps             | 3115 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2178        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008856703 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0194     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.84        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1995        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009437516 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0758      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006492586 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 59.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1872         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0065396666 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 62.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1848        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011325367 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 53.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1834        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004783177 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 74.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1829         |
# |    iterations           | 8            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0068169413 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.499        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.16         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 54.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1826        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012404437 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00961    |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1825        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004137624 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.86        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 23          |
# -----------------------------------------

# %% [markdown]
# ## 4. Save and Reload Model

# %%
PPO_Path = os.path.join("Training", "Saved Models", "PPO_Model_Cartpole")

# %%
PPO_Path
# Out:
# 'Training\\Saved Models\\PPO_Model_Cartpole'

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# ## 5. Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (200.0, 0.0)

# %% [markdown]
# ## 6. Test Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(obs) # Now using Model here
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[200.]
# Episode:4 Score:[200.]
# Episode:5 Score:[200.]

# %%
env.close()

# %% [markdown]
# ## 7. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, "PPO_12").replace("\\", "/")

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_12'

# %%
# %load_ext tensorboard
# %tensorboard --logdir={training_log_path}
# Out:
#       <iframe id="tensorboard-frame-e55ed573e0080b46" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e55ed573e0080b46");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 8. Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_15
# -----------------------------
# | time/              |      |
# |    fps             | 3203 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2241        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008949058 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00142    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 46          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2059        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012322624 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 28.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1972        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007750975 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 49.5        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=195.80 +/- 7.00
# Episode length: 195.80 +/- 7.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 196          |
# |    mean_reward          | 196          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0069142897 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0167      |
# |    value_loss           | 56           |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 1857  |
# |    iterations      | 5     |
# |    time_elapsed    | 5     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1846        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010198498 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1831         |
# |    iterations           | 7            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0093250545 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00923     |
# |    value_loss           | 54.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1822         |
# |    iterations           | 8            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0044212956 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 64.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1810        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003666322 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 22.5        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.004015087 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -3.15e-05   |
# |    value_loss           | 13          |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ## 9. Changing Policies

# %%
net_arch = [dict(pi=[128, 128, 128, 128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# C:\Users\Colin Caban\anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_16
# -----------------------------
# | time/              |      |
# |    fps             | 2885 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1819        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014730032 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.000669   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1619        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014045844 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 27.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1537        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011578244 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 44.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.011333703 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1439  |
# |    iterations      | 5     |
# |    time_elapsed    | 7     |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 6            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0057853325 |
# |    clip_fraction        | 0.0814       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00936     |
# |    value_loss           | 22.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0102398265 |
# |    clip_fraction        | 0.0992       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.536       |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.05         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00793     |
# |    value_loss           | 18.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003999902 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.91        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 5.72        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1389         |
# |    iterations           | 9            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0071788896 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 6.1          |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0075755063 |
# |    clip_fraction        | 0.0806       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.536       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.246        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00566     |
# |    value_loss           | 2.7          |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1366  |
# |    iterations      | 10    |
# |    time_elapsed    | 14    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## 10. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 16094    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4250     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 153      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.509    |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3686     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 240      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.462    |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3455     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 322      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.42     |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0